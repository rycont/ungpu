# %% [markdown]
# # 2. 코로나바이러스
# ## 2.1. 문제 정의 및 가설 수립
# - 국가별 코로나바이러스 확진자 통계
# - 미국의 확진자가 가장 많을것이다

# %% [markdown]
# ## 2.2. 데이터 가져오기

# %%
# !kaggle datasets download -d imdevskp/corona-virus-report
# Out:
# /bin/bash: kaggle: command not found

# %%
# !unzip ./corona-virus-report.zip
# Out:
# Archive:  ./corona-virus-report.zip
# replace country_wise_latest.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %% [markdown]
# ## 2.3. 데이터 로드하기

# %%
import numpy as np
import pandas as pd
import matplotlib.font_manager as font_manager
import matplotlib as mpl

font_manager.fontManager.ttflist.append(font_manager.FontEntry(
    fname='/usr/share/fonts/truetype/nanum/NanumSquareRound.ttf',
    name='NanumSquareRound'))
mpl.rcParams['font.family'] = 'NanumSquareRound'

# mpl.rcParams['font.family'] = 'My Custom Font'
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./covid_19_clean_complete.csv')

# %%
df.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %% [markdown]
# ## 2.4. 데이터 살펴보기

# %%
df.shape
# Out:
# (49068, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.7+ MB

# %%
df.isnull().sum()
# Out:
# Province/State    34404
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %%
df['Country/Region'].value_counts()
# Out:
# China             6204
# Canada            2256
# United Kingdom    2068
# France            2068
# Australia         1504
#                   ...
# Uganda             188
# Gabon              188
# Singapore          188
# Cabo Verde         188
# Gambia             188
# Name: Country/Region, Length: 187, dtype: int64

# %%
df.Date.min(), df.Date.max()
# Out:
# ('2020-01-22', '2020-07-27')

# %%
df['Date'] = pd.to_datetime(df.Date)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  datetime64[ns]
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(4), object(3)
# memory usage: 3.7+ MB

# %%
df.columns = ('지역', '국가', '위도', '경도', '날짜', '확진자', '사망자', '회복자', '치료중', 'WHO')

# %% [markdown]
# ## 2.5. EDA(탐색적 데이터 분석)
# ### 2.5.1. 대한민국 코로나 데이터 분석

# %%
df[df['국가'].str.contains('Korea')]
# Out:
#         지역           국가         위도          경도         날짜    확진자  사망자    회복자  \
# 141    NaN  South Korea  35.907757  127.766922 2020-01-22      1    0      0
# 402    NaN  South Korea  35.907757  127.766922 2020-01-23      1    0      0
# 663    NaN  South Korea  35.907757  127.766922 2020-01-24      2    0      0
# 924    NaN  South Korea  35.907757  127.766922 2020-01-25      2    0      0
# 1185   NaN  South Korea  35.907757  127.766922 2020-01-26      3    0      0
# ...    ...          ...        ...         ...        ...    ...  ...    ...
# 47904  NaN  South Korea  35.907757  127.766922 2020-07-23  13979  298  12817
# 48165  NaN  South Korea  35.907757  127.766922 2020-07-24  14092  298  12866
# 48426  NaN  South Korea  35.907757  127.766922 2020-07-25  14150  298  12890
# 48687  NaN  South Korea  35.907757  127.766922 2020-07-26  14175  299  12905
# 48948  NaN  South Korea  35.907757  127.766922 2020-07-27  14203  300  13007
#
#        치료중              WHO
# 141      1  Western Pacific
# 402      1  Western Pacific
# 663      2  Western Pacific
# 924      2  Western Pacific
# 1185     3  Western Pacific
# ...    ...              ...
# 47904  864  Western Pacific
# 48165  928  Western Pacific
# 48426  962  Western Pacific
# 48687  971  Western Pacific
# 48948  896  Western Pacific
#
# [188 rows x 10 columns]

# %%
koreaDf = df[df['국가'] == 'South Korea']
koreaDf
# Out:
#         지역           국가         위도          경도         날짜    확진자  사망자    회복자  \
# 141    NaN  South Korea  35.907757  127.766922 2020-01-22      1    0      0
# 402    NaN  South Korea  35.907757  127.766922 2020-01-23      1    0      0
# 663    NaN  South Korea  35.907757  127.766922 2020-01-24      2    0      0
# 924    NaN  South Korea  35.907757  127.766922 2020-01-25      2    0      0
# 1185   NaN  South Korea  35.907757  127.766922 2020-01-26      3    0      0
# ...    ...          ...        ...         ...        ...    ...  ...    ...
# 47904  NaN  South Korea  35.907757  127.766922 2020-07-23  13979  298  12817
# 48165  NaN  South Korea  35.907757  127.766922 2020-07-24  14092  298  12866
# 48426  NaN  South Korea  35.907757  127.766922 2020-07-25  14150  298  12890
# 48687  NaN  South Korea  35.907757  127.766922 2020-07-26  14175  299  12905
# 48948  NaN  South Korea  35.907757  127.766922 2020-07-27  14203  300  13007
#
#        치료중              WHO
# 141      1  Western Pacific
# 402      1  Western Pacific
# 663      2  Western Pacific
# 924      2  Western Pacific
# 1185     3  Western Pacific
# ...    ...              ...
# 47904  864  Western Pacific
# 48165  928  Western Pacific
# 48426  962  Western Pacific
# 48687  971  Western Pacific
# 48948  896  Western Pacific
#
# [188 rows x 10 columns]

# %%
sns.lineplot(x='날짜', y='확진자', data=koreaDf)
sns.lineplot(x='날짜', y='사망자', data=koreaDf)
sns.lineplot(x='날짜', y='회복자', data=koreaDf)
plt.legend(['Active', 'Dead', 'Recovered'])
plt.show()
# Out:
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/textpath.py:65: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/textpath.py:65: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/textpath.py:65: RuntimeWarning: Glyph 54869 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/textpath.py:65: RuntimeWarning: Glyph 51652 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/textpath.py:65: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 54869 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51652 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 54869 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 51652 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## 2.5.2. 국가별 코로나 데이터 분석

# %%
latestDf = df[df['날짜'] == df['날짜'].max()]
latestDf.head()
# Out:
#         지역           국가        위도         경도         날짜    확진자   사망자    회복자  \
# 48807  NaN  Afghanistan  33.93911  67.709953 2020-07-27  36263  1269  25198
# 48808  NaN      Albania  41.15330  20.168300 2020-07-27   4880   144   2745
# 48809  NaN      Algeria  28.03390   1.659600 2020-07-27  27973  1163  18837
# 48810  NaN      Andorra  42.50630   1.521800 2020-07-27    907    52    803
# 48811  NaN       Angola -11.20270  17.873900 2020-07-27    950    41    242
#
#         치료중                    WHO
# 48807  9796  Eastern Mediterranean
# 48808  1991                 Europe
# 48809  7973                 Africa
# 48810    52                 Europe
# 48811   667                 Africa

# %%
sortedDf = latestDf.sort_values(by="확진자", ascending=False)
sortedDf.head(10)
# Out:
#         지역              국가         위도          경도         날짜      확진자     사망자  \
# 49030  NaN              US  40.000000 -100.000000 2020-07-27  4290259  148011
# 48835  NaN          Brazil -14.235000  -51.925300 2020-07-27  2442375   87618
# 48936  NaN           India  20.593684   78.962880 2020-07-27  1480073   33408
# 48992  NaN          Russia  61.524010  105.318756 2020-07-27   816680   13334
# 49005  NaN    South Africa -30.559500   22.937500 2020-07-27   452529    7067
# 48963  NaN          Mexico  23.634500 -102.552800 2020-07-27   395489   44022
# 48986  NaN            Peru  -9.190000  -75.015200 2020-07-27   389717   18418
# 48854  NaN           Chile -35.675100  -71.543000 2020-07-27   347923    9187
# 49028  NaN  United Kingdom  55.378100   -3.436000 2020-07-27   300111   45759
# 48938  NaN            Iran  32.427908   53.688046 2020-07-27   293606   15912
#
#            회복자      치료중                    WHO
# 49030  1325804  2816444               Americas
# 48835  1846641   508116               Americas
# 48936   951166   495499        South-East Asia
# 48992   602249   201097                 Europe
# 49005   274925   170537                 Africa
# 48963   303810    47657               Americas
# 48986   272547    98752               Americas
# 48854   319954    18782               Americas
# 49028        0   254352                 Europe
# 48938   255144    22550  Eastern Mediterranean

# %%
plt.figure(
    figsize=(10, 5)
)
sns.barplot(
    x='국가',
    y='확진자',
    data=sortedDf.head(10)
)
plt.xticks(rotation=45)
plt.show()
# Out:
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/textpath.py:65: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/textpath.py:65: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/textpath.py:65: RuntimeWarning: Glyph 54869 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/textpath.py:65: RuntimeWarning: Glyph 51652 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/textpath.py:65: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 54869 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51652 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 54869 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 51652 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
worldWideDf = df.groupby('날짜')[['확진자', '사망자', '회복자']].sum().reset_index()
worldWideDf.head()
# Out:
#           날짜   확진자  사망자  회복자
# 0 2020-01-22   555   17   28
# 1 2020-01-23   654   18   30
# 2 2020-01-24   941   26   36
# 3 2020-01-25  1434   42   39
# 4 2020-01-26  2118   56   52

# %%
sns.lineplot(x='날짜', y='확진자', data=worldWideDf)
sns.lineplot(x='날짜', y='회복자', data=worldWideDf)
sns.lineplot(x='날짜', y='사망자', data=worldWideDf)

plt.show()
# Out:
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/textpath.py:65: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/textpath.py:65: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/textpath.py:65: RuntimeWarning: Glyph 54869 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/textpath.py:65: RuntimeWarning: Glyph 51652 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/textpath.py:65: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 54869 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51652 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 54869 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 51652 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0, flags=flags)
