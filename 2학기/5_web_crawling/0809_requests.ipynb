# %% [markdown]
# # 1. requests 모듈

# %%
import requests

# %% [markdown]
# ## 1.1. Get으로 데이터 요청하기
# - requests.get(url)
# - query paramter[?key=value&key1=value1]

# %%
params = {
    "key": "value"
}
r = requests.get('http://httpbin.org/get', params)

# %%
r.json()
# Out:
# {'args': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.25.1',
#   'X-Amzn-Trace-Id': 'Root=1-6114866b-461b339b42a9a1b403b9061f'},
#  'origin': '52.187.48.228',
#  'url': 'http://httpbin.org/get?key=value'}

# %%
r.headers['Date']
# Out:
# 'Thu, 12 Aug 2021 02:24:43 GMT'

# %%
r.status_code
# Out:
# 200

# %% [markdown]
# ## POST 방식

# %%
url = 'https://search.naver.com/search.naver'
params = {
    'query': "디미고"
}
res = requests.get(url, params)
res.text
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="디미고 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'디미고\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'디미고\'의 네이버 통합검색 결과입니다."> <title>디미고 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_210805.css"> <link rel="stylesheet" type="text/css" hr
# ...

# %%
r = requests.get("https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=105&oid=001&aid=0012592366", headers={
    'User-Agent': "asdf"
})

if r.ok: print(r.text[:1000])
else: print("Error")
# Out:
# <!DOCTYPE HTML>
# <html lang="ko">
# <head>
# <meta charset="euc-kr">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="referrer" contents="always">
# <meta name="viewport" content="width=1106" />
# <title>KT "코로나19 백신접종 예약시스템 안정화 지원" : 네이버 뉴스</title>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <meta property="me2:post_tag"		content="연합뉴스 : 네이버뉴스"/>
# <meta property="me2:category1"		content="연합뉴스"/>
# <meta property="me2:category2"		content="IT/과학"/>
# <meta property="me2:image"			content="https://imgnews.pstatic.net/image/001/2021/08/11/AKR20210811058700017_01_i_P4_20210811102011929.jpg"/>
#
# <meta property="og:title"			content="KT &quot;코로나19 백신접종 예약시스템 안정화 지원&quot;"/>
# <meta property="og:type"			content="article"/>
# <meta property="og:url"				content="https://news.naver.com/main/read.naver?mode=LSD&mid=sec&oid=001&aid=0012592366&sid1=001"/>
# ...
