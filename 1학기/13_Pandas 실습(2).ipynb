# %% [markdown]
# # 13. Pandas 실습 (2)

# %%
# numpy, pandas import하기
import numpy as np
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-837425f2c769> in <module>
#       1 # numpy, pandas import하기
#       2 import numpy as np
# ----> 3 import pandas as pd
#
# ~/.local/lib/python3.8/site-packages/pandas/__init__.py in <module>
#      49 import pandas.core.config_init
#      50
# ---> 51 from pandas.core.api import (
#      52     # dtype
#      53     Int8Dtype,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/api.py in <module>
#      29 from pandas.core.construction import array
#      30 from pandas.core.flags import Flags
# ---> 31 from pandas.core.groupby import Grouper, NamedAgg
#      32 from pandas.core.indexes.api import (
#      33     CategoricalIndex,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/__init__.py in <module>
# ----> 1 from pandas.core.groupby.generic import DataFrameGroupBy, NamedAgg, SeriesGroupBy
#       2 from pandas.core.groupby.groupby import GroupBy
#       3 from pandas.core.groupby.grouper import Grouper
#       4
#       5 __all__ = [
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/generic.py in <module>
#      63 import pandas.core.common as com
#      64 from pandas.core.construction import create_series_with_explicit_dtype
# ---> 65 from pandas.core.frame import DataFrame
#      66 from pandas.core.generic import NDFrame
#      67 from pandas.core.groupby import base
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in <module>
#     117 from pandas.core.dtypes.missing import isna, notna
#     118
# --> 119 from pandas.core import algorithms, common as com, generic, nanops, ops
#     120 from pandas.core.accessor import CachedAccessor
#     121 from pandas.core.aggregation import (
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in <module>
#     111 from pandas.core.window import Expanding, ExponentialMovingWindow, Rolling, Window
#     112
# --> 113 from pandas.io.formats import format as fmt
#     114 from pandas.io.formats.format import (
#     115     DataFrameFormatter,
#
# ~/.local/lib/python3.8/site-packages/pandas/io/formats/format.py in <module>
#      75 from pandas.core.reshape.concat import concat
#      76
# ---> 77 from pandas.io.common import stringify_path
#      78 from pandas.io.formats.printing import adjoin, justify, pprint_thing
#      79
#
# ~/.local/lib/python3.8/site-packages/pandas/io/common.py in <module>
#       1 """Common IO api utilities"""
#       2
# ----> 3 import bz2
#       4 import codecs
#       5 from collections import abc
#
# /opt/python/3.8.6/lib/python3.8/bz2.py in <module>
#      17 from threading import RLock
#      18
# ---> 19 from _bz2 import BZ2Compressor, BZ2Decompressor
#      20
#      21
#
# ModuleNotFoundError: No module named '_bz2'

# %% [markdown]
# ## 13-1. 데이터 불러오기

# %%
# 'http://bit.ly/student-score-2' URL로부터 csv 파일 불러오기 (첫번째 DataFrame)
# Out:
#     학년  반  번호    이름  성별    국어    수학
# 0    1  3   1    지민  남자  95.3  88.8
# 1    1  3   2  지드래곤  남자  91.9  79.3
# 2    1  3   3  강다니엘  남자  74.8  90.0
# 3    1  4   1     뷔  남자  88.8   NaN
# 4    1  4   2    화사  여자  88.1  87.6
# 5    1  4   3    정국  남자  90.0   NaN
# 6    1  5   1    민현  남자  78.5  77.8
# 7    1  5   2    소연  여자  83.2  75.2
# 8    1  5   3     진  남자  93.3  88.4
# 9    1  6   1   하성운  남자  85.4  78.8
# 10   1  6   2    태연  여자  88.8  81.0
# 11   1  6   3   차은우  남자  90.0  89.9

# %% [markdown]
# ## 13-2. 결측값 확인하기

# %%
# 결측값 갯수세기 (isnull() 이용)
# Out:
# 학년    0
# 반     0
# 번호    0
# 이름    0
# 성별    0
# 국어    0
# 수학    2
# dtype: int64

# %%
# 수학 점수에 결측값이 있는 행데이터 보기
# Out:
#    학년  반  번호  이름  성별    국어  수학
# 3   1  4   1   뷔  남자  88.8 NaN
# 5   1  4   3  정국  남자  90.0 NaN

# %% [markdown]
# ## 13-3. 결측값 처리하기

# %%
# 수학 점수 평균구하기 (소숫점 첫째자리까지)
# Out:
# 83.7

# %%
# 수학 점수의 결측값을 평균값으로 채우기
# Out:
#     학년  반  번호    이름  성별    국어    수학
# 0    1  3   1    지민  남자  95.3  88.8
# 1    1  3   2  지드래곤  남자  91.9  79.3
# 2    1  3   3  강다니엘  남자  74.8  90.0
# 3    1  4   1     뷔  남자  88.8  83.7
# 4    1  4   2    화사  여자  88.1  87.6
# 5    1  4   3    정국  남자  90.0  83.7
# 6    1  5   1    민현  남자  78.5  77.8
# 7    1  5   2    소연  여자  83.2  75.2
# 8    1  5   3     진  남자  93.3  88.4
# 9    1  6   1   하성운  남자  85.4  78.8
# 10   1  6   2    태연  여자  88.8  81.0
# 11   1  6   3   차은우  남자  90.0  89.9

# %%
# 결측값 갯수세기 (isnull() 이용)
# Out:
# 학년    0
# 반     0
# 번호    0
# 이름    0
# 성별    0
# 국어    0
# 수학    0
# dtype: int64

# %% [markdown]
# ## 13-4. 자료형 변환하기

# %%
# 국어, 수학 컬럼의 자료형을 float -> int로 변환하기
# Out:
#     학년  반  번호    이름  성별  국어  수학
# 0    1  3   1    지민  남자  95  88
# 1    1  3   2  지드래곤  남자  91  79
# 2    1  3   3  강다니엘  남자  74  90
# 3    1  4   1     뷔  남자  88  83
# 4    1  4   2    화사  여자  88  87
# 5    1  4   3    정국  남자  90  83
# 6    1  5   1    민현  남자  78  77
# 7    1  5   2    소연  여자  83  75
# 8    1  5   3     진  남자  93  88
# 9    1  6   1   하성운  남자  85  78
# 10   1  6   2    태연  여자  88  81
# 11   1  6   3   차은우  남자  90  89

# %% [markdown]
# ## 13-5. DataFrame 합치기

# %%
# 'http://bit.ly/student-score-3' URL로부터 csv 파일 불러오기 (두번째 DataFrame)
# Out:
#       이름  영어   IT
# 0     지민  79  100
# 1   지드래곤  80   95
# 2   강다니엘  88   91
# 3      뷔  90   89
# 4     화사  89   90
# 5     정국  85   88
# 6     민현  80   81
# 7     소연  81   88
# 8      진  88   80
# 9    하성운  70   80
# 10    태연  79   85
# 11   차은우  85   99

# %%
# 두개의 DataFrame을 열방향으로 합치기 (concat() 사용)
# Out:
#     학년  반  번호    이름  성별  국어  수학    이름  영어   IT
# 0    1  3   1    지민  남자  95  88    지민  79  100
# 1    1  3   2  지드래곤  남자  91  79  지드래곤  80   95
# 2    1  3   3  강다니엘  남자  74  90  강다니엘  88   91
# 3    1  4   1     뷔  남자  88  83     뷔  90   89
# 4    1  4   2    화사  여자  88  87    화사  89   90
# 5    1  4   3    정국  남자  90  83    정국  85   88
# 6    1  5   1    민현  남자  78  77    민현  80   81
# 7    1  5   2    소연  여자  83  75    소연  81   88
# 8    1  5   3     진  남자  93  88     진  88   80
# 9    1  6   1   하성운  남자  85  78   하성운  70   80
# 10   1  6   2    태연  여자  88  81    태연  79   85
# 11   1  6   3   차은우  남자  90  89   차은우  85   99

# %% [markdown]
# ## 13-6. DataFrame 데이터 삭제하기

# %%
# 첫번째 DataFrame에서 지드래곤 삭제하기
# Out:
#     학년  반  번호    이름  성별  국어  수학
# 0    1  3   1    지민  남자  95  88
# 2    1  3   3  강다니엘  남자  74  90
# 3    1  4   1     뷔  남자  88  83
# 4    1  4   2    화사  여자  88  87
# 5    1  4   3    정국  남자  90  83
# 6    1  5   1    민현  남자  78  77
# 7    1  5   2    소연  여자  83  75
# 8    1  5   3     진  남자  93  88
# 9    1  6   1   하성운  남자  85  78
# 10   1  6   2    태연  여자  88  81
# 11   1  6   3   차은우  남자  90  89

# %%
# 첫번째 DataFrame index reset하기 (reset_index() 이용하기)
# Out:
#     학년  반  번호    이름  성별  국어  수학
# 0    1  3   1    지민  남자  95  88
# 1    1  3   3  강다니엘  남자  74  90
# 2    1  4   1     뷔  남자  88  83
# 3    1  4   2    화사  여자  88  87
# 4    1  4   3    정국  남자  90  83
# 5    1  5   1    민현  남자  78  77
# 6    1  5   2    소연  여자  83  75
# 7    1  5   3     진  남자  93  88
# 8    1  6   1   하성운  남자  85  78
# 9    1  6   2    태연  여자  88  81
# 10   1  6   3   차은우  남자  90  89

# %%
# 두번째 DataFrame에서 뷔, 정국 삭제하기
# Out:
#       이름  영어   IT
# 0     지민  79  100
# 1   지드래곤  80   95
# 2   강다니엘  88   91
# 4     화사  89   90
# 6     민현  80   81
# 7     소연  81   88
# 8      진  88   80
# 9    하성운  70   80
# 10    태연  79   85
# 11   차은우  85   99

# %%
# 두번째 DataFrame index reset하기 (reset_index() 이용하기)
# Out:
#      이름  영어   IT
# 0    지민  79  100
# 1  지드래곤  80   95
# 2  강다니엘  88   91
# 3    화사  89   90
# 4    민현  80   81
# 5    소연  81   88
# 6     진  88   80
# 7   하성운  70   80
# 8    태연  79   85
# 9   차은우  85   99

# %% [markdown]
# ## 13-7. DataFrame 병합하기

# %%
# 두개의 DataFrame을 '이름' 기준으로 left 방식으로 merge하기
# Out:
#     학년  반  번호    이름  성별  국어  수학    영어     IT
# 0    1  3   1    지민  남자  95  88  79.0  100.0
# 1    1  3   3  강다니엘  남자  74  90  88.0   91.0
# 2    1  4   1     뷔  남자  88  83   NaN    NaN
# 3    1  4   2    화사  여자  88  87  89.0   90.0
# 4    1  4   3    정국  남자  90  83   NaN    NaN
# 5    1  5   1    민현  남자  78  77  80.0   81.0
# 6    1  5   2    소연  여자  83  75  81.0   88.0
# 7    1  5   3     진  남자  93  88  88.0   80.0
# 8    1  6   1   하성운  남자  85  78  70.0   80.0
# 9    1  6   2    태연  여자  88  81  79.0   85.0
# 10   1  6   3   차은우  남자  90  89  85.0   99.0

# %%
# 두개의 DataFrame을 '이름' 기준으로 right 방식으로 merge하기
# Out:
#     학년    반   번호    이름   성별    국어    수학  영어   IT
# 0  1.0  3.0  1.0    지민   남자  95.0  88.0  79  100
# 1  NaN  NaN  NaN  지드래곤  NaN   NaN   NaN  80   95
# 2  1.0  3.0  3.0  강다니엘   남자  74.0  90.0  88   91
# 3  1.0  4.0  2.0    화사   여자  88.0  87.0  89   90
# 4  1.0  5.0  1.0    민현   남자  78.0  77.0  80   81
# 5  1.0  5.0  2.0    소연   여자  83.0  75.0  81   88
# 6  1.0  5.0  3.0     진   남자  93.0  88.0  88   80
# 7  1.0  6.0  1.0   하성운   남자  85.0  78.0  70   80
# 8  1.0  6.0  2.0    태연   여자  88.0  81.0  79   85
# 9  1.0  6.0  3.0   차은우   남자  90.0  89.0  85   99

# %%
# 두개의 DataFrame을 '이름' 기준으로 inner 방식으로 merge하기
# Out:
#    학년  반  번호    이름  성별  국어  수학  영어   IT
# 0   1  3   1    지민  남자  95  88  79  100
# 1   1  3   3  강다니엘  남자  74  90  88   91
# 2   1  4   2    화사  여자  88  87  89   90
# 3   1  5   1    민현  남자  78  77  80   81
# 4   1  5   2    소연  여자  83  75  81   88
# 5   1  5   3     진  남자  93  88  88   80
# 6   1  6   1   하성운  남자  85  78  70   80
# 7   1  6   2    태연  여자  88  81  79   85
# 8   1  6   3   차은우  남자  90  89  85   99

# %%
# 두개의 DataFrame을 '이름' 기준으로 outer 방식으로 merge하기
# Out:
#      학년    반   번호    이름   성별    국어    수학    영어     IT
# 0   1.0  3.0  1.0    지민   남자  95.0  88.0  79.0  100.0
# 1   1.0  3.0  3.0  강다니엘   남자  74.0  90.0  88.0   91.0
# 2   1.0  4.0  1.0     뷔   남자  88.0  83.0   NaN    NaN
# 3   1.0  4.0  2.0    화사   여자  88.0  87.0  89.0   90.0
# 4   1.0  4.0  3.0    정국   남자  90.0  83.0   NaN    NaN
# 5   1.0  5.0  1.0    민현   남자  78.0  77.0  80.0   81.0
# 6   1.0  5.0  2.0    소연   여자  83.0  75.0  81.0   88.0
# 7   1.0  5.0  3.0     진   남자  93.0  88.0  88.0   80.0
# 8   1.0  6.0  1.0   하성운   남자  85.0  78.0  70.0   80.0
# 9   1.0  6.0  2.0    태연   여자  88.0  81.0  79.0   85.0
# 10  1.0  6.0  3.0   차은우   남자  90.0  89.0  85.0   99.0
# 11  NaN  NaN  NaN  지드래곤  NaN   NaN   NaN  80.0   95.0

# %% [markdown]
# ## 13-8. 데이터 변환하기
# * 90점 이상: 'A', 80점 이상: 'B', 70점 이상: 'C', 그외: 'D' 부여하기
# * 예) 국어점수가 95점인 경우 [국어등급] 컬럼에 'A' 넣기

# %%
# Apply 함수 작성하기

# %%
# 첫번째 DataFrame에 국어, 수학 과목의 등급 부여하기
# Out:
#     학년  반  번호    이름  성별  국어  수학 국어등급 수학등급
# 0    1  3   1    지민  남자  95  88    A    B
# 1    1  3   3  강다니엘  남자  74  90    C    A
# 2    1  4   1     뷔  남자  88  83    B    B
# 3    1  4   2    화사  여자  88  87    B    B
# 4    1  4   3    정국  남자  90  83    A    B
# 5    1  5   1    민현  남자  78  77    C    C
# 6    1  5   2    소연  여자  83  75    B    C
# 7    1  5   3     진  남자  93  88    A    B
# 8    1  6   1   하성운  남자  85  78    B    C
# 9    1  6   2    태연  여자  88  81    B    B
# 10   1  6   3   차은우  남자  90  89    A    B

# %%
# 국어등급 별 갯수 세기
# Out:
# B    5
# A    4
# C    2
# Name: 국어등급, dtype: int64

# %%
# 수학등급 별 갯수 세기
# Out:
# B    7
# C    3
# A    1
# Name: 수학등급, dtype: int64

# %% [markdown]
# ## 13-9. 데이터 그룹핑하기

# %%
# pivot_table을 사용하여 반과 성별에 따른 국어, 수학 평균 구하기
# Out:
#       국어          수학
# 성별    남자    여자    남자    여자
# 반
# 3   84.5   NaN  89.0   NaN
# 4   89.0  88.0  83.0  87.0
# 5   85.5  83.0  82.5  75.0
# 6   87.5  88.0  83.5  81.0

# %%
# groupby를 사용하여 반과 성별에 따른 국어, 수학 평균 구하기
# Out:
#         국어    수학
# 반 성별
# 3 남자  84.5  89.0
# 4 남자  89.0  83.0
#   여자  88.0  87.0
# 5 남자  85.5  82.5
#   여자  83.0  75.0
# 6 남자  87.5  83.5
#   여자  88.0  81.0

# %%
print(__name__)
# Out:
# __main__
